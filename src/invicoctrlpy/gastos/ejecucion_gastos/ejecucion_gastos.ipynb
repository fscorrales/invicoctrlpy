# %% [markdown]
# # REPORTES DE EJECUCION DE OBRAS

# %% [markdown]
# La finalidad de los presentes reportes es exponer la ejecución presupuestaria de obras (partidas 421 y 422) y, más específcamente, la ejecución de Módulos Básicos (Programa 29). La información contenida en los mismos será útil para tareas de control y, especialmente, para la elaboración de los Estados Contables

# %% [markdown]
# ## Datos iniciales

# %% [markdown]
# El único dato que debería modificarse es el relativo al ejercicio sobre el cual se pretende trabajar.

# %%
from invicoctrlpy.gastos.ejecucion_gastos.ejecucion_gastos import EjecucionGastos

import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('mode.chained_assignment',None)

import itables
itables.options.lengthMenu = [10, 50, 100, -1]
itables.options.maxBytes = 0

from  pivottablejs import pivot_ui

EJERCICIO = '2023'
UPDATE_DB = False
ejecucion_gastos = EjecucionGastos(ejercicio=EJERCICIO, update_db=UPDATE_DB)

# %% [markdown]
# ## Reportes

# %% [markdown]
# ## Tablas Auxiliares

# %% [markdown]
# ### Ejecucion SIIF con Descripcion hasta el ejercicio seleccionado

# %%
siif_ejec_gastos = ejecucion_gastos.import_siif_gtos_desc()
itables.show(siif_ejec_gastos, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="5e6939fe-10e0-41c0-872e-f97a58a644ea" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>ejercicio</th>
#       <th>estructura</th>
#       <th>partida</th>
#       <th>fuente</th>
#       <th>desc_prog</th>
#       <th>desc_subprog</th>
#       <th>desc_proy</th>
#       <th>desc_act</th>
#       <th>credito_original</th>
#       <th>credito_vigente</th>
#       <th>comprometido</th>
#       <th>ordenado</th>
#       <th>saldo</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>ejercicio</th><th>estructura</th><th>partida</th><th>fuente</th><th>desc_prog</th><th>desc_subprog</th><th>desc_proy</th><th>desc_act</th><th>credito_original</th><th>credito_vigente</th><th>comprometido</th><th>ordenado</th><th>saldo</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
TIVIDADES CENTRALES", "00 - --", "00 - --", "01 - DIRECCION Y COORDINACION SUPERIOR", "2,224,000.00", "2,224,000.00", "0.00", "0.00", "2,224,000.00"], ["2023", "01-00-00-01-141", "141", "11", "01 - ACTIVIDADES CENTRALES", "00 - --", "00 - --", "01 - DIRECCION Y COORDINACION SUPERIOR", "7,944,000.00", "7,944,000.00", "1,023,980.00", "1,023,980.00", "6,920,020.00"], ["2023", "01-00-00-01-151", "151", "11", "01 - ACTIVIDADES CENTRALES", "00 - --", "00 - --", "01 - DIRECCION Y COORDINACION SUPERIOR", "5,254,000.00", "5,254,000.00", "469,217.89", "469,217.89", "4,784,782.11"], ["2023", "01-00-00-01-161", "161", "11", "01 - ACTIVIDADES CENTRALES", "00 - --", "00 - --", "01 - DIRECCION Y COORDINACION SUPERIOR", "2,627,000.00", "2,627,000.00", "0.00", "0.00", "2,627,000.00"], ["2023", "01-00-00-01-211", "211", "11", "01 - ACTIVIDADES CENTRALES", "00 - --", "00 - --", "01 - DIRECCION Y COORDINACION SUPERIOR", "1,030,000.00", "1,030,000.00", "249,718.41", "249,718.41", "780,281.59"], ["2023", "01-00-00-01-215", "215", "11", "01 - ACTIVIDADES CENTRALES", "00 - --", "00 - --", "01 - DIRECCION Y COORDINACION SUPERIOR", "1,000.00", "1,000.00", "0.00", "0.00",  ...

# %%
siif_gastos = ejecucion_gastos.import_siif_comprobantes()
itables.show(siif_gastos, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="6cfe8c56-12d7-4fbb-a6a3-c924d2d6eb6d" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ejercicio</th>
#       <th>mes</th>
#       <th>fecha</th>
#       <th>nro_comprobante</th>
#       <th>importe</th>
#       <th>partida</th>
#       <th>nro_entrada</th>
#       <th>nro_origen</th>
#       <th>nro_expte</th>
#       <th>glosa</th>
#       <th>beneficiario</th>
#       <th>nro_fondo</th>
#       <th>fuente</th>
#       <th>cta_cte</th>
#       <th>cuit</th>
#       <th>clase_reg</th>
#       <th>clase_mod</th>
#       <th>clase_gto</th>
#       <th>es_comprometido</th>
#       <th>es_verificado</th>
#       <th>es_aprobado</th>
#       <th>es_pagado</th>
#       <th>desc_partida</th>
#       <th>part_parcial</th>
#       <th>desc_part_parcial</th>
#       <th>grupo</th>
#       <th>desc_grupo</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>ejercicio</th><th>mes</th><th>fecha</th><th>nro_comprobante</th><th>importe</th><th>partida</th><th>nro_entrada</th><th>nro_origen</th><th>nro_expte</th><th>glosa</th><th>beneficiario</th><th>nro_fondo</th><th>fuente</th><th>cta_cte</th><th>cuit</th><th>clase_reg</th><th>clase_mod</th><th>clase_gto</th><th>es_comprometido</th><th>es_verificado</th><th>es_aprobado</th><th>es_pagado</th><th>desc_partida</th><th>part_parcial</th><th>desc_part_parcial</th><th>grupo</th><th>desc_grupo</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0, "2023", "01/2023", "2023-01-19", "00012/23", "204,736.41", "111", "12", "12", "900002342023", "LIQUIDACION HABERES ENERO 2023/ PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [1, "2023", "01/2023", "2023-01-19", "00012/23", "464,312.89", "111", "12", "12", "900002342023", "LIQUIDACION HABERES ENERO 2023/ PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [2, "2023", "01/2023", "2023-01-19", "00012/23", "827,309.57", "111", "12", "12", "900002342023", "LIQUIDACION HABERES ENERO 2023/ PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [3, "2023", "01/2023", "2023-01-19", "00012/23", "396,867.53", "111", "12", "12", "900002342023", "LIQUIDACION HABERES ENERO 2023/ PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [4, "2023", "01/2023", "2023-01-19", "00012/23", "1,103,419.38", "111", "12", "12", "900002342023", "LIQUIDACION HABERES ENERO 2023/ PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [5, "2023", "01/2023", "2023-01-19", "00012/23", "327,659.06", "111", "12", "12", "900002342023", "LIQUIDACION HABERES ENERO 2023/ PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [6, "2023", "02/2023", "2023-02-17", "00168/23", "806,970.27", "111", "168", "168", "900009402023", "LIQUIDACION HABERERES FEBRERO 2023- PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [7, "2023", "02/2023", "2023-02-17", "00168/23", "396,867.53", "111", "168", "168", "900009402023", "LIQUIDACION HABERERES FEBRERO 2023- PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [8, "2023", "02/2023", "2023-02-17", "00168/23", "327,659.06", "111", "168", "168", "900009402023", "LIQUIDACION HABERERES FEBRERO 2023- PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [9, "2023", "02/2023", "2023-02-17", "00168/23", "1,103,419.38", "111", "168", "168", "900009402023", "LIQUIDACION HABERERES FEBRERO 2023- PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN PERSONAL"], [10, "2023", "02/2023", "2023-02-17", "00168/23", "464,312.89", "111", "168", "168", "900009402023", "LIQUIDACION HABERERES FEBRERO 2023- PLANTA ", "INSTITUTO DE VIVIENDA DE CORRIENTES", "None", "11", "130832-04", "30632351514", "CYO", "NOR", "REM", "True", "True", "True", "True", "RETRIBUCION DEL CARGO", "110", "PERSONAL PERMANENTE", "100", "GASTOS EN ...

# %% [markdown]
# ## EXTRA:

# %% [markdown]
# ### Excel

# %%
# with pd.ExcelWriter('Planillometro al ' + EJERCICIO + '.xlsx') as writer:
#     siif_ejec_obras_actual.to_excel(writer, sheet_name='EjecuccionSIIF' + EJERCICIO, index=False)
#     siif_desc_icaro_actual = ejecucion_obras.import_siif_obras_desc_icaro()
#     siif_desc_icaro_actual.to_excel(writer, sheet_name='EjecuccionSIIFDescICARO' + EJERCICIO, index=False)
#     planillometro.to_excel(writer, sheet_name='Planillometro', index=False)
#     planillometro_full_icaro = ejecucion_obras.reporte_planillometro(full_icaro=True, es_desc_siif=False)
#     planillometro_full_icaro.to_excel(writer, sheet_name='PlanillometroFullIcaro', index=False)
